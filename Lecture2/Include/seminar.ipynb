# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("https://klue.kr/login")

time.sleep(1)

# %%
# id와 pw를 입력하는 창의 요소 정보 획득
input = driver.find_elements(By.XPATH, '//input')
# 클루 아이디
id = "hge2020"
# 비밀번호
pw = "awsd258~"
# 아이디를 입력
input[0].send_keys(id)
# 비밀번호 입력
input[1].send_keys(pw)
# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# %%
def scroll():
    #페이지의 맨 끝에 다다랐는지 확인하고 그렇지 않다면 계속해서 end 키를 누르는 코드.
    elem = driver.find_element(By.TAG_NAME, "body")

    #스크롤길이정보 획득
    last_height = driver.execute_script("return document.body.scrollHeight")

    #계속해서반복
    while True:
            #end키 3번 누르기
        for i in range(3):
            elem.send_keys(Keys.END)
            time.sleep(0.2)
        
            #이번 스크롤 길이정보 획득
        new_height = driver.execute_script("return document.body.scrollHeight")

            #만약 새 스크롤 길이정보가 이전과 달라지지 않았다면
        if new_height == last_height:
            print("********" + "break********")
                    #루프 종료
            return
            #직전 스크롤 길이정보에 이번 스크롤 길이정보값을 할당
        last_height = new_height

# %%
def cal_satis(li):
    for i, elem in enumerate(li):
        if (elem.get_attribute('src').split('/')[-1] != 'orange-pow.svg'):
            return i
    return 5

# %%
driver.get('https://klue.kr/search?query=ACADEMIC%20ENGLISH%E2%85%A1&sort=year_term')
scroll()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 driver.get('https://klue.kr/search?query=ACADEMIC%20ENGLISH%E2%85%A1&sort=year_term')
# ----> 2 scroll()
#
# Cell In[6], line 12, in scroll()
#       9 while True:
#      10         #end키 3번 누르기
#      11     for i in range(3):
# ---> 12         elem.send_keys(Keys.END)
#      13         time.sleep(0.2)
#      15         #이번 스크롤 길이정보 획득
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webelement.py:231, in WebElement.send_keys(self, *value)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=227'>228</a>             remote_files.append(self._upload(file))
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=228'>229</a>         value = "\n".join(remote_files)
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=230'>231</a> self._execute(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=231'>232</a>     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=232'>233</a> )
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=392'>393</a>     params = {}
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=393'>394</a> params["id"] = self._id
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=394'>395</a> return self._parent.execute(command, params)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=341'>342</a>     elif "sessionId" not in params:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=342'>343</a>         params["sessionId"] = self.session_id
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=344'>345</a> response = self.command_executor.execute(driver_command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=345'>346</a> if response:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=346'>347</a>     self.error_handler.check_response(response)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=299'>300</a> trimmed = self._trim_large_entries(params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=300'>301</a> LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=301'>302</a> return self._request(command_info[0], url, body=data)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=318'>319</a>     body = None
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=320'>321</a> if self.keep_alive:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=321'>322</a>     response = self._conn.request(method, url, body=body, headers=headers)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=322'>323</a>     statuscode = response.status
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=323'>324</a> else:
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=135'>136</a>     return self.request_encode_url(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=136'>137</a>         method,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=137'>138</a>         url,
#    (...)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=140'>141</a>         **urlopen_kw,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=141'>142</a>     )
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=142'>143</a> else:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=143'>144</a>     return self.request_encode_body(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=144'>145</a>         method, url, fields=fields, headers=headers, **urlopen_kw
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=145'>146</a>     )
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=274'>275</a>     extra_kw["headers"].setdefault("Content-Type", content_type)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=276'>277</a> extra_kw.update(urlopen_kw)
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=278'>279</a> return self.urlopen(method, url, **extra_kw)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=441'>442</a>     response = conn.urlopen(method, url, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=442'>443</a> else:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=443'>444</a>     response = conn.urlopen(method, u.request_uri, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=445'>446</a> redirect_location = redirect and response.get_redirect_location()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=446'>447</a> if not redirect_location:
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=789'>790</a> response_conn = conn if not release_conn else None
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=791'>792</a> # Make the request on the HTTPConnection object
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=792'>793</a> response = self._make_request(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=793'>794</a>     conn,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=794'>795</a>     method,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=795'>796</a>     url,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=796'>797</a>     timeout=timeout_obj,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=797'>798</a>     body=body,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=798'>799</a>     headers=headers,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=799'>800</a>     chunked=chunked,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=800'>801</a>     retries=retries,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=801'>802</a>     response_conn=response_conn,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=802'>803</a>     preload_content=preload_content,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=803'>804</a>     decode_content=decode_content,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=804'>805</a>     **response_kw,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=805'>806</a> )
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=807'>808</a> # Everything went great!
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=808'>809</a> clean_exit = True
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=534'>535</a> # Receive the response from the server
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=535'>536</a> try:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=536'>537</a>     response = conn.getresponse()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=537'>538</a> except (BaseSSLError, OSError) as e:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=538'>539</a>     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=462'>463</a> from .response import HTTPResponse
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=464'>465</a> # Get the response from http.client.HTTPConnection
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=465'>466</a> httplib_response = super().getresponse()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=467'>468</a> try:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=468'>469</a>     assert_header_parsing(httplib_response.msg)
#
# File C:\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1371'>1372</a> try:
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1372'>1373</a>     try:
# -> <a href='file:///c%3A/Python310/lib/http/client.py?line=1373'>1374</a>         response.begin()
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1374'>1375</a>     except ConnectionError:
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1375'>1376</a>         self.close()
#
# File C:\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=315'>316</a> # read until we get a non-100 response
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=316'>317</a> while True:
# --> <a href='file:///c%3A/Python310/lib/http/client.py?line=317'>318</a>     version, status, reason = self._read_status()
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=318'>319</a>     if status != CONTINUE:
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=319'>320</a>         break
#
# File C:\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=277'>278</a> def _read_status(self):
# --> <a href='file:///c%3A/Python310/lib/http/client.py?line=278'>279</a>     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=279'>280</a>     if len(line) > _MAXLINE:
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=280'>281</a>         raise LineTooLong("status line")
#
# File C:\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     <a href='file:///c%3A/Python310/lib/socket.py?line=702'>703</a> while True:
#     <a href='file:///c%3A/Python310/lib/socket.py?line=703'>704</a>     try:
# --> <a href='file:///c%3A/Python310/lib/socket.py?line=704'>705</a>         return self._sock.recv_into(b)
#     <a href='file:///c%3A/Python310/lib/socket.py?line=705'>706</a>     except timeout:
#     <a href='file:///c%3A/Python310/lib/socket.py?line=706'>707</a>         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#접근할 각 강의평가 목록을 가져옵니다
elements = driver.find_elements(By.XPATH, '//ul/div/div/li')
#각 정보를 담을 리스트를 생성합니다
links, 학기, 학수번호, 교수명, 강의시간 = [], [],[],[],[]
학습량, 난이도, 학점, 성취감, 강의만족도 = [],[],[],[],[]

#for문을 사용하여 elements의 각 element를 탐색합니다.
for i, element in enumerate(elements):
    #평가정보 div의 윗단 div를 top으로 선언
    links.append(element.find_element(By.XPATH, 'a').get_attribute('href'))
    top =  element.find_element(By.XPATH, 'a/div[1]')
    #top에서 학기와 학수번호 정보를 가져옵니다.(2019년 2학기 - KECE208(03))
    li = top.find_element(By.XPATH, 'p[1]').text.split(' - ') #정보가 ' - '로 나뉘어있으므로, 해당 값을 기준으로 정보를 분할합니다.

    #각 정보를 필요한 리스트에 담습니다.
    학기.append(li[0])
    학수번호.append(li[1])
    
    #평가정보 div의 아랫단 div를 bottom으로 선언
    bottom = element.find_element(By.XPATH, 'a/div[2]')

    #bottom에서 교수명을 가져와 리스트에 담습니다.
    교수명.append(bottom.find_element(By.XPATH, 'div[1]/p[2]/span').text)
    강의시간.append(bottom.find_element(By.XPATH, 'div[1]/p[3]').text.split('#')[1])

    #오래된 강의의 강의평에 대해서는 학습량, 난이도, 학점, 성취감 정보가 존재하지 않는 경우가 있습니다.
    #존재하지 않는 영역의 값을 가져올땐 오류가 발생하므로, try-except문을 사용하여 오류처리를 해줍니다.
    try:
        학습량.append(bottom.find_element(By.XPATH, 'div[2]/div/div[1]/span[2]').text)
        난이도.append(bottom.find_element(By.XPATH, 'div[2]/div/div[2]/span[2]').text)
        학점.append(bottom.find_element(By.XPATH, 'div[2]/div/div[3]/span[2]').text)
        성취감.append(bottom.find_element(By.XPATH, 'div[2]/div/div[4]/span[2]').text)
    except:
        #강의평가 요약을 지원하지 않는 강의일 경우
        print("강의평가 요약을 지원하지 않는 강의입니다")
        학습량.append('-')
        난이도.append('-')
        학점.append('-')
        성취감.append('-')

    #bottom에서 강의만족도를 가져와 리스트에 담습니다.
    강의만족도.append(bottom.find_element(By.XPATH, 'div[3]/div/span').text)
    
    #가져온 값들을 출력합니다.
    print(f"학기: {학기[i]} 학수번호: {교수명[i]} 교수명: {교수명[i]} 강의시간: {강의시간[i]}")
    print(f"학습량: {학습량[i]}, 난이도: {난이도[i]}, 학점: {학점[i]}, 성취감: {성취감[i]} 강의만족도: {강의만족도[i]}")
    print(links[i])
# Out:
# 학기: 2023년 겨울학기 학수번호: Alexander Vos 교수명: Alexander Vos 강의시간: 월(5-6) 화(5-6) 수(5-6) 목(5-6)
# 학습량: 3.5, 난이도: 3.5, 학점: 4.0, 성취감: 4.0 강의만족도: 4.0
# https://klue.kr/lectures/140398
# 학기: 2023년 2학기 학수번호: David M. Docherty 교수명: David M. Docherty 강의시간: 월(1) 수(1)
# 학습량: 2.4, 난이도: 2.3, 학점: 3.0, 성취감: 3.0 강의만족도: 4.3
# https://klue.kr/lectures/137729
# 학기: 2023년 2학기 학수번호: David M. Docherty 교수명: David M. Docherty 강의시간: 월(2) 수(2)
# 학습량: 2.5, 난이도: 2.6, 학점: 3.3, 성취감: 2.9 강의만족도: 3.9
# https://klue.kr/lectures/137730
# 학기: 2023년 2학기 학수번호: David M. Docherty 교수명: David M. Docherty 강의시간: 화(3) 목(3)
# 학습량: 2.6, 난이도: 2.8, 학점: 3.3, 성취감: 3.2 강의만족도: 4.3
# https://klue.kr/lectures/137731
# 학기: 2023년 2학기 학수번호: Anthony Hanf 교수명: Anthony Hanf 강의시간: 화(1) 목(1)
# 학습량: 3.1, 난이도: 2.5, 학점: 4.2, 성취감: 3.6 강의만족도: 4.6
# https://klue.kr/lectures/137732
# 학기: 2023년 2학기 학수번호: Anthony Hanf 교수명: Anthony Hanf 강의시간: 화(2) 목(2)
# 학습량: 2.4, 난이도: 2.2, 학점: 4.6, 성취감: 4.0 강의만족도: 4.8
# https://klue.kr/lectures/137733
# 학기: 2023년 2학기 학수번호: Anthony Hanf 교수명: Anthony Hanf 강의시간: 월(3) 수(3)
# 학습량: 2.4, 난이도: 2.2, 학점: 4.6, 성취감: 3.3 강의만족도: 4.6
# https://klue.kr/lectures/137734
# 학기: 2023년 2학기 학수번호: Anthony Death 교수명: Anthony Death 강의시간: 월(2) 수(2)
# 학습량: 3.5, 난이도: 2.9, 학점: 3.3, 성취감: 3.2 강의만족도: 3.8
# https://klue.kr/lectures/137735
# 학기: 2023년 2학기 학수번호: Anthony Death 교수명: Anthony Death 강의시간: 월(3) 수(3)
# 학습량: 2.9, 난이도: 3.1, 학점: 2.6, 성취감: 3.0 강의만족도: 3.9
# https://klue.kr/lectures/137736
# 학기: 2023년 2학기 학수번호: Anthony Death 교수명: Anthony Death 강의시간: 화(2) 목(2)
# 학습량: 3.8, 난이도: 3.7, 학점: 2.3, 성취감: 2.0 강의만족도: 2.8
# https://klue.kr/lectures/137737
# 학기: 2023년 2학기 학수번호: Paulette M. Hawkins 교수명: Paulette M. Hawkins 강의시간: 월(4) 수(4)
# 학습량: 3.4, 난이도: 2.7, 학점: 2.8, 성취감: 2.7 강의만족도: 3.4
# https://klue.kr/lectures/137738
# 학기: 2023년 2학기 학수번호: Paulette M. Hawkins 교수명: Paulette M. Hawkins 강의시간: 화(5) 목(5)
# 학습량: 3.7, 난이도: 2.9, 학점: 3.3, 성취감: 2.9 강의만족도: 3.7
# https://klue.kr/lectures/137739
# 학기: 2023년 2학기 학수번호: Paulette M. Hawkins 교수명: Paulette M. Hawkins 강의시간: 화(6) 목(6)
# 학습량: 3.8, 난이도: 3.3, 학점: 2.3, 성취감: 2.5 강의만족도: 3.3
# https://klue.kr/lectures/137740
# 학기: 2023년 2학기 학수번호: Derek Winchester 교수명: Derek Winchester 강의시간: 월(5) 수(5)
# 학습량: 3.3, 난이도: 2.5, 학점: 4.3, 성취감: 3.9 강의만족도: 4.6
# https://klue.kr/lectures/137741
# 학기: 2023년 2학기 학수번호: Derek Winchester 교수명: Derek Winchester 강의시간: 월(6) 수(6)
# 학습량: 3.0, 난이도: 2.7, 학점: 4.1, 성취감: 3.6 강의만족도: 4.6
# https://klue.kr/lectures/137742
# 학기: 2023년 2학기 학수번호: Derek Winchester 교수명: Derek Winchester 강의시간: 화(4) 목(4)
# 학습량: 2.8, 난이도: 2.9, 학점: 4.0, 성취감: 3.8 강의만족도: 4.8
# https://klue.kr/lectures/137743
# 학기: 2023년 2학기 학수번호: Glenn P. Sundeen 교수명: Glenn P. Sundeen 강의시간: 월(5) 수(5)
# 학습량: 3.5, 난이도: 3.1, 학점: 4.4, 성취감: 3.8 강의만족도: 4.1
# https://klue.kr/lectures/137744
# 학기: 2023년 2학기 학수번호: Glenn P. Sundeen 교수명: Glenn P. Sundeen 강의시간: 화(3) 목(3)
# 학습량: 3.4, 난이도: 2.8, 학점: 4.4, 성취감: 3.2 강의만족도: 4.2
# https://klue.kr/lectures/137745
# 학기: 2023년 2학기 학수번호: Glenn P. Sundeen 교수명: Glenn P. Sundeen 강의시간: 화(4) 목(4)
# 학습량: 2.5, 난이도: 2.5, 학점: 4.5, 성취감: 3.5 강의만족도: 5.0
# https://klue.kr/lectures/137746
# 학기: 2023년 2학기 학수번호: Peter S. Sylvestre 교수명: Peter S. Sylvestre 강의시간: 월(4) 수(4)
# 학습량: 2.3, 난이도: 2.6, 학점: 2.6, 성취감: 3.3 강의만족도: 4.3
# https://klue.kr/lectures/137747
# 학기: 2023년 2학기 학수번호: Peter S. Sylvestre 교수명: Peter S. Sylvestre 강의시간: 화(4) 목(4)
# 학습량: 2.7, 난이도: 2.7, 학점: 3.0, 성취감: 3.5 강의만족도: 4.0
# https://klue.kr/lectures/137748
# 학기: 2023년 2학기 학수번호: Dara Seamus Fox 교수명: Dara Seamus Fox 강의시간: 월(3) 수(3)
# 학습량: 3.2, 난이도: 2.8, 학점: 3.9, 성취감: 3.1 강의만족도: 4.0
# https://klue.kr/lectures/137749
# 학기: 2023년 2학기 학수번호: Dara Seamus Fox 교수명: Dara Seamus Fox 강의시간: 월(5) 수(5)
# 학습량: 3.7, 난이도: 3.1, 학점: 3.7, 성취감: 2.6 강의만족도: 4.0
# https://klue.kr/lectures/137750
# 학기: 2023년 2학기 학수번호: Dara Seamus Fox 교수명: Dara Seamus Fox 강의시간: 화(6) 목(6)
# 학습량: 4.3, 난이도: 2.3, 학점: 3.7, 성취감: 2.0 강의만족도: 3.3
# https://klue.kr/lectures/137751
# 학기: 2023년 2학기 학수번호: Michael A. Mumford 교수명: Michael A. Mumford 강의시간: 월(4) 수(4)
# 학습량: 3.4, 난이도: 2.8, 학점: 4.5, 성취감: 3.9 강의만족도: 4.5
# https://klue.kr/lectures/137752
# 학기: 2023년 2학기 학수번호: Michael A. Mumford 교수명: Michael A. Mumford 강의시간: 화(5) 목(5)
# 학습량: 4.2, 난이도: 3.8, 학점: 4.2, 성취감: 3.0 강의만족도: 3.4
# https://klue.kr/lectures/137753
# 학기: 2023년 2학기 학수번호: Michael A. Mumford 교수명: Michael A. Mumford 강의시간: 월(3) 수(3)
# 학습량: 3.3, 난이도: 3.1, 학점: 4.3, 성취감: 3.3 강의만족도: 3.9
# https://klue.kr/lectures/137754
# 학기: 2023년 2학기 학수번호: Michael A. Mumford 교수명: Michael A. Mumford 강의시간: 화(6) 목(6)
# 학습량: 4.0, 난이도: 3.4, 학점: 4.6, 성취감: 4.2 강의만족도: 4.4
# https://klue.kr/lectures/137755
# 학기: 2023년 2학기 학수번호: Michael A. Mumford 교수명: Michael A. Mumford 강의시간: 화(4) 목(4)
# 학습량: 4.6, 난이도: 4.0, 학점: 2.9, 성취감: 1.7 강의만족도: 3.0
# https://klue.kr/lectures/137756
# 학기: 2023년 2학기 학수번호: Mark Robert Eade 교수명: Mark Robert Eade 강의시간: 월(5) 수(5)
# 학습량: 3.5, 난이도: 3.1, 학점: 2.7, 성취감: 2.7 강의만족도: 3.7
# https://klue.kr/lectures/137757
# 학기: 2023년 2학기 학수번호: Mark Robert Eade 교수명: Mark Robert Eade 강의시간: 월(6) 수(6)
# 학습량: 2.4, 난이도: 2.8, 학점: 3.1, 성취감: 3.3 강의만족도: 4.5
# https://klue.kr/lectures/137758
# 학기: 2023년 2학기 학수번호: Mark Robert Eade 교수명: Mark Robert Eade 강의시간: 화(3) 목(3)
# 학습량: 3.3, 난이도: 3.0, 학점: 3.5, 성취감: 2.8 강의만족도: 4.0
# https://klue.kr/lectures/137759
# 학기: 2023년 2학기 학수번호: Mark Robert Eade 교수명: Mark Robert Eade 강의시간: 화(5) 목(5)
# 학습량: 3.3, 난이도: 4.2, 학점: 3.5, 성취감: 3.3 강의만족도: 4.2
# https://klue.kr/lectures/137760
# 학기: 2023년 2학기 학수번호: Alexander Vos 교수명: Alexander Vos 강의시간: 월(3) 수(3)
# 학습량: 3.6, 난이도: 3.1, 학점: 4.1, 성취감: 3.7 강의만족도: 4.1
# https://klue.kr/lectures/137761
# 학기: 2023년 2학기 학수번호: Alexander Vos 교수명: Alexander Vos 강의시간: 화(1) 목(1)
# 학습량: 3.8, 난이도: 3.8, 학점: 4.5, 성취감: 3.8 강의만족도: 3.7
# https://klue.kr/lectures/137762
# 학기: 2023년 2학기 학수번호: Alexander Vos 교수명: Alexander Vos 강의시간: 화(2) 목(2)
# 학습량: 4.3, 난이도: 4.1, 학점: 4.4, 성취감: 3.8 강의만족도: 3.4
# https://klue.kr/lectures/137763
# 학기: 2023년 2학기 학수번호: Kirstie Bromenshenk 교수명: Kirstie Bromenshenk 강의시간: 월(1) 수(1)
# 학습량: 2.9, 난이도: 2.8, 학점: 3.9, 성취감: 3.1 강의만족도: 4.4
# https://klue.kr/lectures/137764
# 학기: 2023년 2학기 학수번호: Kirstie Bromenshenk 교수명: Kirstie Bromenshenk 강의시간: 월(2) 수(2)
# 학습량: 3.1, 난이도: 2.8, 학점: 3.8, 성취감: 2.9 강의만족도: 3.9
# https://klue.kr/lectures/137765
# 학기: 2023년 2학기 학수번호: Kirstie Bromenshenk 교수명: Kirstie Bromenshenk 강의시간: 화(2) 목(2)
# 학습량: 2.4, 난이도: 2.6, 학점: 3.7, 성취감: 3.4 강의만족도: 4.3
# https://klue.kr/lectures/137766
# 학기: 2023년 2학기 학수번호: Kirstie Bromenshenk 교수명: Kirstie Bromenshenk 강의시간: 월(3) 수(3)
# 학습량: 2.1, 난이도: 2.2, 학점: 3.3, 성취감: 2.3 강의만족도: 3.8
# https://klue.kr/lectures/137767
# 학기: 2023년 2학기 학수번호: Thomas Walsh 교수명: Thomas Walsh 강의시간: 월(2) 수(2)
# 학습량: 4.0, 난이도: 3.3, 학점: 4.3, 성취감: 3.7 강의만족도: 3.8
# https://klue.kr/lectures/137768
# 학기: 2023년 2학기 학수번호: Thomas Walsh 교수명: Thomas Walsh 강의시간: 화(3) 목(3)
# 학습량: 3.8, 난이도: 3.0, 학점: 4.3, 성취감: 3.6 강의만족도: 4.3
# https://klue.kr/lectures/137769
# 학기: 2023년 2학기 학수번호: Thomas Walsh 교수명: Thomas Walsh 강의시간: 화(4) 목(4)
# 학습량: 3.5, 난이도: 2.9, 학점: 4.3, 성취감: 3.3 강의만족도: 3.7
# https://klue.kr/lectures/137770
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 월(3) 수(3)
# 학습량: 4.3, 난이도: 3.8, 학점: 3.9, 성취감: 3.5 강의만족도: 3.5
# https://klue.kr/lectures/137771
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 월(4) 수(4)
# 학습량: 4.5, 난이도: 3.7, 학점: 4.3, 성취감: 4.0 강의만족도: 4.0
# https://klue.kr/lectures/137772
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 화(1) 목(1)
# 학습량: 3.7, 난이도: 3.3, 학점: 4.0, 성취감: 3.2 강의만족도: 4.0
# https://klue.kr/lectures/137773
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 월(2) 수(2)
# 학습량: 4.3, 난이도: 3.3, 학점: 5.0, 성취감: 3.3 강의만족도: 3.7
# https://klue.kr/lectures/137774
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 화(2) 목(2)
# 학습량: 4.6, 난이도: 3.3, 학점: 4.4, 성취감: 3.1 강의만족도: 3.6
# https://klue.kr/lectures/137775
# 학기: 2023년 2학기 학수번호: Darius Goodwin 교수명: Darius Goodwin 강의시간: 화(3) 목(3)
# 학습량: 4.0, 난이도: 1.7, 학점: 4.7, 성취감: 4.3 강의만족도: 4.7
# https://klue.kr/lectures/137776
# 학기: 2023년 2학기 학수번호: Peter L. Sinclair 교수명: Peter L. Sinclair 강의시간: 월(1) 수(1)
# 학습량: 3.4, 난이도: 3.9, 학점: 4.0, 성취감: 3.1 강의만족도: 3.9
# https://klue.kr/lectures/137777
# 학기: 2023년 2학기 학수번호: Peter L. Sinclair 교수명: Peter L. Sinclair 강의시간: 월(2) 수(2)
# 학습량: 3.0, 난이도: 3.3, 학점: 3.8, 성취감: 2.8 강의만족도: 3.5
# https://klue.kr/lectures/137778
# 학기: 2023년 2학기 학수번호: Peter L. Sinclair 교수명: Peter L. Sinclair 강의시간: 화(2) 목(2)
# 학습량: 3.0, 난이도: 2.7, 학점: 4.0, 성취감: 3.7 강의만족도: 4.2
# https://klue.kr/lectures/137779
# 학기: 2023년 2학기 학수번호: Russell Mason 교수명: Russell Mason 강의시간: 월(6) 수(6)
# 학습량: 3.8, 난이도: 3.4, 학점: 4.1, 성취감: 3.8 강의만족도: 4.3
# https://klue.kr/lectures/137780
# 학기: 2023년 2학기 학수번호: Russell Mason 교수명: Russell Mason 강의시간: 월(4) 수(4)
# 학습량: 4.2, 난이도: 3.6, 학점: 4.3, 성취감: 3.6 강의만족도: 4.2
# https://klue.kr/lectures/137781
# 학기: 2023년 2학기 학수번호: Patrice Reidy 교수명: Patrice Reidy 강의시간: 화(4) 목(4)
# 학습량: 2.9, 난이도: 2.6, 학점: 3.0, 성취감: 2.6 강의만족도: 3.6
# https://klue.kr/lectures/137782
# 학기: 2023년 2학기 학수번호: Patrice Reidy 교수명: Patrice Reidy 강의시간: 화(5) 목(5)
# 학습량: 2.2, 난이도: 2.2, 학점: 2.6, 성취감: 2.2 강의만족도: 3.4
# https://klue.kr/lectures/137783
# 학기: 2023년 2학기 학수번호: Hudson Lim 교수명: Hudson Lim 강의시간: 월(3) 수(3)
# 학습량: 2.0, 난이도: 1.9, 학점: 4.8, 성취감: 3.8 강의만족도: 4.8
# https://klue.kr/lectures/137784
# 학기: 2023년 2학기 학수번호: Hudson Lim 교수명: Hudson Lim 강의시간: 화(1) 목(1)
# 학습량: 2.0, 난이도: 1.8, 학점: 4.8, 성취감: 4.3 강의만족도: 4.3
# https://klue.kr/lectures/137785
# 학기: 2023년 2학기 학수번호: Hudson Lim 교수명: Hudson Lim 강의시간: 화(2) 목(2)
# 학습량: 2.6, 난이도: 2.1, 학점: 4.8, 성취감: 4.1 강의만족도: 4.8
# https://klue.kr/lectures/137786
# 학기: 2023년 2학기 학수번호: Hudson Lim 교수명: Hudson Lim 강의시간: 화(3) 목(3)
# 학습량: 2.3, 난이도: 2.0, 학점: 4.8, 성취감: 4.5 강의만족도: 5.0
# https://klue.kr/lectures/137787
# 학기: 2023년 2학기 학수번호: Hudson Lim 교수명: Hudson Lim 강의시간: 화(4) 목(4)
# 학습량: 1.6, 난이도: 1.6, 학점: 5.0, 성취감: 4.0 강의만족도: 5.0
# https://klue.kr/lectures/137788
# 학기: 2023년 2학기 학수번호: Youn-Soo Chang 교수명: Youn-Soo Chang 강의시간: 월(1) 수(1)
# 학습량: 4.0, 난이도: 3.4, 학점: 4.3, 성취감: 4.1 강의만족도: 4.5
# https://klue.kr/lectures/137789
# 학기: 2023년 2학기 학수번호: Youn-Soo Chang 교수명: Youn-Soo Chang 강의시간: 월(2) 수(2)
# 학습량: 3.8, 난이도: 3.4, 학점: 4.4, 성취감: 4.3 강의만족도: 4.6
# https://klue.kr/lectures/137790
# 학기: 2023년 2학기 학수번호: Youn-Soo Chang 교수명: Youn-Soo Chang 강의시간: 화(2) 목(2)
# 학습량: 4.5, 난이도: 3.5, 학점: 3.5, 성취감: 3.0 강의만족도: 3.5
# https://klue.kr/lectures/137791
# 학기: 2023년 2학기 학수번호: Youn-Soo Chang 교수명: Youn-Soo Chang 강의시간: 화(1) 목(1)
# 학습량: 4.2, 난이도: 3.3, 학점: 4.9, 성취감: 4.1 강의만족도: 4.6
# https://klue.kr/lectures/137792
# 학기: 2023년 2학기 학수번호: Youn-Soo Chang 교수명: Youn-Soo Chang 강의시간: 월(3) 수(3)
# 학습량: 4.3, 난이도: 3.3, 학점: 4.2, 성취감: 3.8 강의만족도: 3.8
# https://klue.kr/lectures/137793
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 월(2) 수(2)
# 학습량: 3.4, 난이도: 2.6, 학점: 3.3, 성취감: 2.5 강의만족도: 3.3
# https://klue.kr/lectures/137794
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 월(3) 수(3)
# 학습량: 3.0, 난이도: 2.8, 학점: 3.7, 성취감: 3.1 강의만족도: 4.0
# https://klue.kr/lectures/137795
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 화(4) 목(4)
# 학습량: 2.8, 난이도: 2.8, 학점: 4.0, 성취감: 4.3 강의만족도: 4.7
# https://klue.kr/lectures/137796
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 월(1) 수(1)
# 학습량: 4.0, 난이도: 3.6, 학점: 3.4, 성취감: 2.6 강의만족도: 2.8
# https://klue.kr/lectures/137797
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 화(2) 목(2)
# 학습량: 3.5, 난이도: 3.5, 학점: 2.5, 성취감: 2.5 강의만족도: 3.7
# https://klue.kr/lectures/137798
# 학기: 2023년 2학기 학수번호: 월쉬널래그첸드라베단 교수명: 월쉬널래그첸드라베단 강의시간: 화(3) 목(3)
# 학습량: 3.0, 난이도: 2.0, 학점: 3.0, 성취감: 1.5 강의만족도: 3.0
# https://klue.kr/lectures/137799
# 학기: 2023년 2학기 학수번호: William du Plessis 교수명: William du Plessis 강의시간: 월(6) 수(6)
# 학습량: 2.0, 난이도: 2.3, 학점: 4.1, 성취감: 4.2 강의만족도: 4.4
# https://klue.kr/lectures/137800
# 학기: 2023년 2학기 학수번호: William du Plessis 교수명: William du Plessis 강의시간: 월(4) 수(4)
# 학습량: 2.3, 난이도: 2.4, 학점: 4.1, 성취감: 3.7 강의만족도: 4.2
# https://klue.kr/lectures/137801
# 학기: 2023년 2학기 학수번호: William du Plessis 교수명: William du Plessis 강의시간: 월(5) 수(5)
# 학습량: 2.4, 난이도: 2.4, 학점: 4.1, 성취감: 3.4 강의만족도: 4.6
# https://klue.kr/lectures/137802
# 학기: 2023년 2학기 학수번호: William du Plessis 교수명: William du Plessis 강의시간: 화(5) 목(5)
# 학습량: 2.5, 난이도: 2.8, 학점: 4.3, 성취감: 2.8 강의만족도: 4.8
# https://klue.kr/lectures/137803
# 학기: 2023년 2학기 학수번호: William du Plessis 교수명: William du Plessis 강의시간: 화(6) 목(6)
# 학습량: 2.0, 난이도: 1.5, 학점: 3.5, 성취감: 2.5 강의만족도: 4.5
# https://klue.kr/lectures/137804
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 월(4) 수(4)
# 학습량: 2.4, 난이도: 2.6, 학점: 3.4, 성취감: 3.1 강의만족도: 4.3
# https://klue.kr/lectures/137805
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 월(5) 수(5)
# 학습량: 3.6, 난이도: 2.9, 학점: 3.9, 성취감: 3.6 강의만족도: 4.1
# https://klue.kr/lectures/137806
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 월(6) 수(6)
# 학습량: 3.0, 난이도: 3.0, 학점: 4.0, 성취감: 3.0 강의만족도: 4.7
# https://klue.kr/lectures/137807
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 화(3) 목(3)
# 학습량: 3.3, 난이도: 2.4, 학점: 4.1, 성취감: 3.1 강의만족도: 4.7
# https://klue.kr/lectures/137808
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 화(4) 목(4)
# 학습량: -, 난이도: -, 학점: -, 성취감: - 강의만족도: -
# https://klue.kr/lectures/137809
# 학기: 2023년 2학기 학수번호: THOMAS COURCHAINE 교수명: THOMAS COURCHAINE 강의시간: 화(5) 목(5)
# 학습량: 3.0, 난이도: 3.0, 학점: 4.7, 성취감: 4.0 강의만족도: 5.0
# https://klue.kr/lectures/137810
# 학기: 2023년 2학기 학수번호: Gil Michael Ian Coombe 교수명: Gil Michael Ian Coombe 강의시간: 월(2) 수(2)
# 학습량: 4.0, 난이도: 4.0, 학점: 4.5, 성취감: 3.5 강의만족도: 4.5
# https://klue.kr/lectures/137811
# 학기: 2023년 2학기 학수번호: Gil Michael Ian Coombe 교수명: Gil Michael Ian Coombe 강의시간: 월(3) 수(3)
# 학습량: 4.0, 난이도: 3.7, 학점: 4.7, 성취감: 4.3 강의만족도: 3.8
# https://klue.kr/lectures/137812
# 학기: 2023년 2학기 학수번호: Gil Michael Ian Coombe 교수명: Gil Michael Ian Coombe 강의시간: 화(1) 목(1)
# 학습량: 4.0, 난이도: 3.5, 학점: 5.0, 성취감: 4.5 강의만족도: 4.5
# https://klue.kr/lectures/137813
# 학기: 2023년 2학기 학수번호: Gil Michael Ian Coombe 교수명: Gil Michael Ian Coombe 강의시간: 화(2) 목(2)
# 학습량: 4.5, 난이도: 3.3, 학점: 5.0, 성취감: 4.3 강의만족도: 4.5
# https://klue.kr/lectures/137814
# 학기: 2023년 2학기 학수번호: Benjamin Fallon 교수명: Benjamin Fallon 강의시간: 월(1) 수(1)
# 학습량: 2.7, 난이도: 2.3, 학점: 4.4, 성취감: 3.3 강의만족도: 4.7
# https://klue.kr/lectures/137815
# 학기: 2023년 2학기 학수번호: Benjamin Fallon 교수명: Benjamin Fallon 강의시간: 월(2) 수(2)
# 학습량: 2.4, 난이도: 2.4, 학점: 4.4, 성취감: 3.8 강의만족도: 4.6
# https://klue.kr/lectures/137816
# 학기: 2023년 2학기 학수번호: Benjamin Fallon 교수명: Benjamin Fallon 강의시간: 화(2) 목(2)
# 학습량: 3.3, 난이도: 3.0, 학점: 4.3, 성취감: 4.3 강의만족도: 5.0
# https://klue.kr/lectures/137817
# 학기: 2023년 2학기 학수번호: Benjamin Fallon 교수명: Benjamin Fallon 강의시간: 화(3) 목(3)
# 학습량: 3.0, 난이도: 3.0, 학점: 4.9, 성취감: 3.1 강의만족도: 4.9
# https://klue.kr/lectures/137818
# 학기: 2023년 2학기 학수번호: David W. Wellbaum 교수명: David W. Wellbaum 강의시간: 월(3) 수(3)
# 학습량: 3.0, 난이도: 3.0, 학점: 4.0, 성취감: 3.5 강의만족도: 4.0
# https://klue.kr/lectures/137819
# 학기: 2023년 2학기 학수번호: David W. Wellbaum 교수명: David W. Wellbaum 강의시간: 월(4) 수(4)
# 학습량: 1.8, 난이도: 2.3, 학점: 4.3, 성취감: 3.8 강의만족도: 4.5
# https://klue.kr/lectures/137820
# 학기: 2023년 2학기 학수번호: David W. Wellbaum 교수명: David W. Wellbaum 강의시간: 월(5) 수(5)
# 학습량: 3.3, 난이도: 3.0, 학점: 4.0, 성취감: 3.3 강의만족도: 4.7
# https://klue.kr/lectures/137821
# 학기: 2023년 2학기 학수번호: David W. Wellbaum 교수명: David W. Wellbaum 강의시간: 화(4) 목(4)
# 학습량: 2.7, 난이도: 2.8, 학점: 4.5, 성취감: 4.5 강의만족도: 4.8
# https://klue.kr/lectures/137822
# 학기: 2023년 2학기 학수번호: David W. Wellbaum 교수명: David W. Wellbaum 강의시간: 화(5) 목(5)
# 학습량: 3.1, 난이도: 3.0, 학점: 4.6, 성취감: 3.5 강의만족도: 4.1
# https://klue.kr/lectures/137823
# 학기: 2023년 2학기 학수번호: Deborah Moon 교수명: Deborah Moon 강의시간: 월(4) 수(4)
# 학습량: 2.7, 난이도: 2.3, 학점: 4.3, 성취감: 3.4 강의만족도: 4.3
# https://klue.kr/lectures/137824
# 학기: 2023년 2학기 학수번호: Deborah Moon 교수명: Deborah Moon 강의시간: 월(5) 수(5)
# 학습량: 3.0, 난이도: 3.0, 학점: 3.0, 성취감: 3.0 강의만족도: 3.5
# https://klue.kr/lectures/137825
# 학기: 2023년 2학기 학수번호: Deborah Moon 교수명: Deborah Moon 강의시간: 화(4) 목(4)
# 학습량: 4.0, 난이도: 3.5, 학점: 4.5, 성취감: 4.5 강의만족도: 5.0
# https://klue.kr/lectures/137826
# 학기: 2023년 2학기 학수번호: Deborah Moon 교수명: Deborah Moon 강의시간: 화(6) 목(6)
# 학습량: -, 난이도: -, 학점: -, 성취감: - 강의만족도: -
# https://klue.kr/lectures/137827

# %%
import pandas as pd
info = pd.DataFrame((zip(학기, 학수번호, 교수명, 강의시간, 학습량, 난이도, 학점, 성취감, 강의만족도)), columns = ["학기", "학수번호", "교수명", "강의시간", "학습량", "난이도", "학점", "성취감", "강의만족도"])
info
# Out:
# C:\Users\GaEunHeo\AppData\Local\Temp\ipykernel_20852\3499073687.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#             학기         학수번호                교수명                          강의시간  \
# 0   2023년 겨울학기  IFLS012(A0)      Alexander Vos  월(5-6) 화(5-6) 수(5-6) 목(5-6)
# 1    2023년 2학기  IFLS012(01)  David M. Docherty                    월(1) 수(1)
# 2    2023년 2학기  IFLS012(02)  David M. Docherty                    월(2) 수(2)
# 3    2023년 2학기  IFLS012(03)  David M. Docherty                    화(3) 목(3)
# 4    2023년 2학기  IFLS012(04)       Anthony Hanf                    화(1) 목(1)
# ..         ...          ...                ...                           ...
# 95   2023년 2학기  IFLS012(95)  David W. Wellbaum                    화(5) 목(5)
# 96   2023년 2학기  IFLS012(96)       Deborah Moon                    월(4) 수(4)
# 97   2023년 2학기  IFLS012(97)       Deborah Moon                    월(5) 수(5)
# 98   2023년 2학기  IFLS012(98)       Deborah Moon                    화(4) 목(4)
# 99   2023년 2학기  IFLS012(A1)       Deborah Moon                    화(6) 목(6)
#
#     학습량  난이도   학점  성취감 강의만족도
# 0   3.5  3.5  4.0  4.0   4.0
# 1   2.4  2.3  3.0  3.0   4.3
# 2   2.5  2.6  3.3  2.9   3.9
# 3   2.6  2.8  3.3  3.2   4.3
# 4   3.1  2.5  4.2  3.6   4.6
# ..  ...  ...  ...  ...   ...
# 95  3.1  3.0  4.6  3.5   4.1
# 96  2.7  2.3  4.3  3.4   4.3
# 97  3.0  3.0  3.0  3.0   3.5
# 98  4.0  3.5  4.5  4.5   5.0
# 99    -    -    -    -     -
#
# [100 rows x 9 columns]

# %%
#각 정보를 담을 리스트를 생성합니다
만족도, 학습량, 난이도, 강의력, 성취감 = [],[],[],[],[]
user_id, 강의평, lecture_id = [],[],[]
#각 강의평가 페이지를 순회합니다.
for i, link in enumerate(links):
    driver.get(link)
    #접근할 각 강의평가 목록을 가져옵니다
    elements = driver.find_elements(By.XPATH, '//section[3]/div/div/div[2]/div/div')
    #for문을 사용하여 elements의 각 element를 탐색합니다.
    for j, element in enumerate(elements):
        top = element.find_element(By.XPATH, 'div/div/div[1]')
        #강의평 데이터를 수집합니다.
        만족도.append(cal_satis(top.find_elements(By.XPATH, 'div/div[1]/div/img')))
        학습량.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[1]/span').text))
        난이도.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[2]/span').text))
        강의력.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[3]/span').text))
        성취감.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[4]/span').text))
        user_id.append(top.find_element(By.XPATH, 'div[2]/div/span').text)
        강의평.append(element.find_element(By.XPATH, 'div/div/div[2]/div').text)
        #강의 id를 추가합니다.
        lecture_id.append(i)
        print(f"만족도{만족도[-1]}, 유저{user_id[-1]}, 강의평{강의평[-1]}, lecture_id{lecture_id[-1]}")
# Out:
# 만족도5, 유저구찮이즈미, 강의평소문보다는 좋아요.
# 할 것도 많이 없구요.
# 다만 성취감이나 학습 효과는 잘 모르겠습니다.
# 커리큘럼이 나쁘진 않은것 같은데, 뭔가 뭔가 뭔가예요, lecture_id8
# 만족도3, 유저허잇짜, 강의평되도록이면 피하세요...원래 하고 싶었던 교수님을 못 잡아서 듣게 되었는데, 꽤나 힘들었습니다.. 출석을 매번 부르시고, 거의 매번 팀활동으로 토론하는 시간이 있었습니다.
#
# 시험도 두 번 보고, 퀴즈와 간단한 인터뷰도 봤습니다. 중간시험은 문제 예시를 주시고, 대략 스스로 답을 찾고 정리한 뒤 보면 돼서 그나마 괜찮았습니다.. 그러나 기말 시험은 영어로 논리적 오류를 분석하고, 그 이유를 적어야 했는데, 공부를 해도 까다롭게 나와서 저에게는 좀 어려웠습니다.. 인터뷰의 경우에는 지금까지 배웠던 내용들에 관해서 교수님께서 질문하시거나 선택적으로 에세이를 써가면 에세이에 관한 질문을 하십니다. 제가 생각했을 때, 인터뷰에서는 거의 점수가 깎이지 않는 것 같습니다. 시험이 많이 중요합니다..
#
# 결론적으로 아잉 치고 해야 할 것도 너무 많고, 점수도 그렇게 잘 주시진 않는듯합니다., lecture_id8
# 만족도4, 유저내일사장, 강의평기말 시험 안갔는데 비쁠 받았습니다. 다들 디아스 교수님 많이 시킨다고 안좋다고 하는데 학점 진짜 잘 주셔요., lecture_id8
# 만족도4, 유저수강신청안하고싶다, 강의평뭐 다방면으로 여러가지를 배웁니다. 논리적인 철학, 주장하는 에세이 글 등을 영어로 배우다보니 조금 어려운 부분이 있지만 시험에는 그다지 어렵게 나오지는 않습니다. 조별과제가 대략 3번 정도 있고 수업 시간에 조별로 이야기하는 것을 많이 시키십니다. 학점은 그냥 A로 만족하시면 듣기 좋은 듯 합니다. 다른 교수님들의 아잉이 더 편하긴 하지만 이냥 저냥 대충 듣고 싶으시다면 디아스 교수님도 나쁘지 않습니다., lecture_id8
# 만족도4, 유저아보카도좋아, 강의평1학기 2학기 모두 디아스 들은 사람입니다.. 에제를 정말 많이 주십니다
# 수업 와서 대놓고 ㅠ맨날 핸드폰만 하던 제 동기도 똑같이 에제 받았어서 어이없엇움 ㅋㅋㅋ
# 근데? 그만큼 수업 태도는 신경 안씀 다른 교수님들은 잠깐 폰 보거나 집중 안하면 점수깎는다던데
# 디아스 교수님은 수업에 온 모두가 다같이 아이패드랑 핸드폰하는데 뭐라 안하심
# 에제도 상관없으면 ㄹㅇ 꿀강인데 에이쁠이어야 하는 분은 비추
# (1학기 때 에이쁠 안주셔서ㅡ 울뻔했는ㄷㅔ 2학기때 겨우 받았어요 ..ㅠㅠ)
# 수업방식이나 진행은 ㄹㅇ 숨겨진 꿀강인데 다들 잘 모르더라고요
# 과제 거의 없고 갑작스러운 발표 안시킴(정정 전 첫수업 때 자기소개 시키긴하는데 점수반영 아닐 것임)
# 팀플 한 번 잇는데 어려운 거 아니라서 할만함
# 과제 해갈 거 없는 게 ㄹㅇ 꿀임, lecture_id8
# 만족도3, 유저티비티비, 강의평he was the best man ive ever met his lecture skill is amazing i loved it
# he give very good grade also, lecture_id8
# 만족도4, 유저정다원, 강의평그냥 수업참여 잘하면 과제점수는 잘받을 수 있는데 시험이 좀 어렵긴 합니다. 근데 시험만 잘보면 출석도 지각처리 없이 해주시고 좋습니다. 스피치도 있긴한데 그건 쉬워서 무난합니다. 에이까진 무난하지만 에플은 어렵습니다, lecture_id8
# 만족도4, 유저도비도비, 강의평친구들 사이에선 기적의 학점 폭격기라고 불리는데 쁠은 어렵지만 에제는 쉬운 기가 막힌 교수님이다., lecture_id8
# 만족도4, 유저옥저, 강의평일단 명강은 아닙니다.. 다만 에제를 씨뿌리듯이 뿌려주시는 것 같아서 나름은 만족합니다..
#
# 시험은 중간고사 한 번 이루어졌고, 기말고사는 인터뷰로 대체했습니다!
#
# 중간고사는 수능 때 했던 부분(알맞은 접사 넣기, thesis 문장 찾기) 이 나오며, 기말고사 인터뷰는 여태까지 했던 활동들을 중심으로 영어로 물어보시고, 이에 대한 답변을 영어로 해주심 됩니다!
#
# 강의 전달력은 영국식 발음이라 많이 떨어지며, 그렇지만 나름 배우는 건 많다고 생각합니다..ㅎㅎ, lecture_id9
# 만족도3, 유저꿀강찾아학점받자, 강의평강의가 너무 어렵습니다. 영어를 잘 못하시면 다른 분 듣는 것을 추천합니다. 그냥 순수하게 내용이 어려운 것이니, 영어를 잘 한다면 오히려 좋으실 수도 있습니다.
# 강의력은 별로고, 학점은 나름 잘 주시는 것 같습니다. 기대 이상입니다., lecture_id9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 14
#      12 #강의평 데이터를 수집합니다.
#      13 만족도.append(cal_satis(top.find_elements(By.XPATH, 'div/div[1]/div/img')))
# ---> 14 학습량.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[1]/span').text))
#      15 난이도.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[2]/span').text))
#      16 강의력.append(int(top.find_element(By.XPATH, 'div/div[2]/div/div[3]/span').text))
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=86'>87</a> @property
#      <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=87'>88</a> def text(self) -> str:
#      <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=88'>89</a>     """The text of the element."""
# ---> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=89'>90</a>     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=392'>393</a>     params = {}
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=393'>394</a> params["id"] = self._id
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webelement.py?line=394'>395</a> return self._parent.execute(command, params)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=341'>342</a>     elif "sessionId" not in params:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=342'>343</a>         params["sessionId"] = self.session_id
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=344'>345</a> response = self.command_executor.execute(driver_command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=345'>346</a> if response:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=346'>347</a>     self.error_handler.check_response(response)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=299'>300</a> trimmed = self._trim_large_entries(params)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=300'>301</a> LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=301'>302</a> return self._request(command_info[0], url, body=data)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=318'>319</a>     body = None
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=320'>321</a> if self.keep_alive:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=321'>322</a>     response = self._conn.request(method, url, body=body, headers=headers)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=322'>323</a>     statuscode = response.status
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/selenium/webdriver/remote/remote_connection.py?line=323'>324</a> else:
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\_request_methods.py:136, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=132'>133</a>     urlopen_kw["body"] = body
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=134'>135</a> if method in self._encode_url_methods:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=135'>136</a>     return self.request_encode_url(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=136'>137</a>         method,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=137'>138</a>         url,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=138'>139</a>         fields=fields,  # type: ignore[arg-type]
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=139'>140</a>         headers=headers,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=140'>141</a>         **urlopen_kw,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=141'>142</a>     )
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=142'>143</a> else:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=143'>144</a>     return self.request_encode_body(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=144'>145</a>         method, url, fields=fields, headers=headers, **urlopen_kw
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=145'>146</a>     )
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\_request_methods.py:183, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=179'>180</a> if fields:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=180'>181</a>     url += "?" + urlencode(fields)
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/_request_methods.py?line=182'>183</a> return self.urlopen(method, url, **extra_kw)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=441'>442</a>     response = conn.urlopen(method, url, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=442'>443</a> else:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=443'>444</a>     response = conn.urlopen(method, u.request_uri, **kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=445'>446</a> redirect_location = redirect and response.get_redirect_location()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/poolmanager.py?line=446'>447</a> if not redirect_location:
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=789'>790</a> response_conn = conn if not release_conn else None
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=791'>792</a> # Make the request on the HTTPConnection object
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=792'>793</a> response = self._make_request(
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=793'>794</a>     conn,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=794'>795</a>     method,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=795'>796</a>     url,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=796'>797</a>     timeout=timeout_obj,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=797'>798</a>     body=body,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=798'>799</a>     headers=headers,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=799'>800</a>     chunked=chunked,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=800'>801</a>     retries=retries,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=801'>802</a>     response_conn=response_conn,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=802'>803</a>     preload_content=preload_content,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=803'>804</a>     decode_content=decode_content,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=804'>805</a>     **response_kw,
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=805'>806</a> )
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=807'>808</a> # Everything went great!
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=808'>809</a> clean_exit = True
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=534'>535</a> # Receive the response from the server
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=535'>536</a> try:
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=536'>537</a>     response = conn.getresponse()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=537'>538</a> except (BaseSSLError, OSError) as e:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connectionpool.py?line=538'>539</a>     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\files\python\seminar2\Lecture2\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=462'>463</a> from .response import HTTPResponse
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=464'>465</a> # Get the response from http.client.HTTPConnection
# --> <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=465'>466</a> httplib_response = super().getresponse()
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=467'>468</a> try:
#     <a href='file:///c%3A/files/python/seminar2/Lecture2/lib/site-packages/urllib3/connection.py?line=468'>469</a>     assert_header_parsing(httplib_response.msg)
#
# File C:\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1371'>1372</a> try:
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1372'>1373</a>     try:
# -> <a href='file:///c%3A/Python310/lib/http/client.py?line=1373'>1374</a>         response.begin()
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1374'>1375</a>     except ConnectionError:
#    <a href='file:///c%3A/Python310/lib/http/client.py?line=1375'>1376</a>         self.close()
#
# File C:\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=315'>316</a> # read until we get a non-100 response
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=316'>317</a> while True:
# --> <a href='file:///c%3A/Python310/lib/http/client.py?line=317'>318</a>     version, status, reason = self._read_status()
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=318'>319</a>     if status != CONTINUE:
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=319'>320</a>         break
#
# File C:\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=277'>278</a> def _read_status(self):
# --> <a href='file:///c%3A/Python310/lib/http/client.py?line=278'>279</a>     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=279'>280</a>     if len(line) > _MAXLINE:
#     <a href='file:///c%3A/Python310/lib/http/client.py?line=280'>281</a>         raise LineTooLong("status line")
#
# File C:\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     <a href='file:///c%3A/Python310/lib/socket.py?line=702'>703</a> while True:
#     <a href='file:///c%3A/Python310/lib/socket.py?line=703'>704</a>     try:
# --> <a href='file:///c%3A/Python310/lib/socket.py?line=704'>705</a>         return self._sock.recv_into(b)
#     <a href='file:///c%3A/Python310/lib/socket.py?line=705'>706</a>     except timeout:
#     <a href='file:///c%3A/Python310/lib/socket.py?line=706'>707</a>         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import pandas as pd
repu = pd.DataFrame((zip(lecture_id, user_id, 만족도, 학습량, 난이도, 학점, 성취감, 강의평)), columns = ["강의아이디","유저아이디", "강의만족도", "학습량", "난이도", "학점", "성취감", "강의평"])
repu
# Out:
#    강의아이디      유저아이디  강의만족도  학습량  난이도   학점  성취감  \
# 0      8      구찮이즈미      5    2    3  4.0    3
# 1      8        허잇짜      3    4    4  3.0    3
# 2      8       내일사장      4    3    3  3.3    3
# 3      8  수강신청안하고싶다      4    3    3  3.3    4
# 4      8     아보카도좋아      4    3    3  4.2    3
# 5      8       티비티비      3    3    3  4.6    3
# 6      8        정다원      4    2    4  4.6    3
# 7      8       도비도비      4    3    2  3.3    2
# 8      9         옥저      4    4    4  2.6    1
# 9      9   꿀강찾아학점받자      3    4    5  2.3    2
#
#                                                  강의평
# 0  소문보다는 좋아요.\n할 것도 많이 없구요.\n다만 성취감이나 학습 효과는 잘 모르...
# 1  되도록이면 피하세요...원래 하고 싶었던 교수님을 못 잡아서 듣게 되었는데, 꽤나 ...
# 2  기말 시험 안갔는데 비쁠 받았습니다. 다들 디아스 교수님 많이 시킨다고 안좋다고 하...
# 3  뭐 다방면으로 여러가지를 배웁니다. 논리적인 철학, 주장하는 에세이 글 등을 영어로...
# 4  1학기 2학기 모두 디아스 들은 사람입니다.. 에제를 정말 많이 주십니다 \n수업 ...
# 5  he was the best man ive ever met his lecture s...
# 6  그냥 수업참여 잘하면 과제점수는 잘받을 수 있는데 시험이 좀 어렵긴 합니다. 근데 ...
# 7  친구들 사이에선 기적의 학점 폭격기라고 불리는데 쁠은 어렵지만 에제는 쉬운 기가 막...
# 8  일단 명강은 아닙니다.. 다만 에제를 씨뿌리듯이 뿌려주시는 것 같아서 나름은 만족합...
# 9  강의가 너무 어렵습니다. 영어를 잘 못하시면 다른 분 듣는 것을 추천합니다. 그냥 ...

# %%
info.to_csv('info_.csv')

# %%
info = pd.read_csv("info.csv", encoding='utf-8')
info
# Out:
#      Unnamed: 0          학기         학수번호                 교수명  \
# 0             0  2023년 겨울학기  IFLS012(A0)       Alexander Vos
# 1             1   2023년 2학기  IFLS012(01)   David M. Docherty
# 2             2   2023년 2학기  IFLS012(02)   David M. Docherty
# 3             3   2023년 2학기  IFLS012(03)   David M. Docherty
# 4             4   2023년 2학기  IFLS012(04)        Anthony Hanf
# ..          ...         ...          ...                 ...
# 255         255   2022년 2학기  IFLS012(84)      Youn-Soo Chang
# 256         256   2022년 2학기  IFLS012(85)          월쉬널래그첸드라베단
# 257         257   2022년 2학기  IFLS012(86)      Youn-Soo Chang
# 258         258   2022년 2학기  IFLS012(87)      Youn-Soo Chang
# 259         259   2022년 2학기  IFLS012(88)  William du Plessis
#
#                              강의시간  학습량  난이도  강의력  성취감 강의만족도
# 0    월(5-6) 화(5-6) 수(5-6) 목(5-6)   3.5  3.5  4.0  4.0   4.0
# 1                      월(1) 수(1)   2.4  2.3  3.0  3.0   4.3
# 2                      월(2) 수(2)   2.5  2.6  3.3  2.9   3.9
# 3                      화(3) 목(3)   2.6  2.8  3.3  3.2   4.3
# 4                      화(1) 목(1)   3.1  2.5  4.2  3.6   4.6
# ..                            ...  ...  ...  ...  ...   ...
# 255                    화(4) 목(4)   4.3  3.0  4.3  3.8   4.0
# 256                    월(3) 수(3)   2.0  2.6  3.9  3.0   4.4
# 257                    화(2) 목(2)   4.1  3.5  4.4  3.5   3.6
# 258                    화(3) 목(3)   3.9  3.4  4.1  3.7   3.9
# 259                    화(6) 목(6)   2.0  2.0  4.0  4.0   4.0
#
# [260 rows x 10 columns]

# %%
학기 = list(info["학기"])
학기
# Out:
# ['2023년 겨울학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 2학기',
#  '2023년 여름학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2023년 1학기',
#  '2022년 겨울학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기',
#  '2022년 2학기']

# %%
def codify(data):
    year = data.split(" ")[0][2:4]
    if data.split(" ")[1] == "1학기":
        semaster = "1"
    elif data.split(" ")[1] == "여름학기":
        semaster = "2"
    elif data.split(" ")[1] == "2학기":
        semaster = "3"
    elif data.split(" ")[1] == "겨울학기":
        semaster = "4"
    return int(year+semaster)

# %%
학기 = list(map(codify, 학기))
학기
# Out:
# [234,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  233,
#  232,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  231,
#  224,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223]

# %%
info["학기"] = 학기
info
# Out:
#      Unnamed: 0   학기         학수번호                 교수명  \
# 0             0  234  IFLS012(A0)       Alexander Vos
# 1             1  233  IFLS012(01)   David M. Docherty
# 2             2  233  IFLS012(02)   David M. Docherty
# 3             3  233  IFLS012(03)   David M. Docherty
# 4             4  233  IFLS012(04)        Anthony Hanf
# ..          ...  ...          ...                 ...
# 255         255  223  IFLS012(84)      Youn-Soo Chang
# 256         256  223  IFLS012(85)          월쉬널래그첸드라베단
# 257         257  223  IFLS012(86)      Youn-Soo Chang
# 258         258  223  IFLS012(87)      Youn-Soo Chang
# 259         259  223  IFLS012(88)  William du Plessis
#
#                              강의시간  학습량  난이도  강의력  성취감 강의만족도
# 0    월(5-6) 화(5-6) 수(5-6) 목(5-6)   3.5  3.5  4.0  4.0   4.0
# 1                      월(1) 수(1)   2.4  2.3  3.0  3.0   4.3
# 2                      월(2) 수(2)   2.5  2.6  3.3  2.9   3.9
# 3                      화(3) 목(3)   2.6  2.8  3.3  3.2   4.3
# 4                      화(1) 목(1)   3.1  2.5  4.2  3.6   4.6
# ..                            ...  ...  ...  ...  ...   ...
# 255                    화(4) 목(4)   4.3  3.0  4.3  3.8   4.0
# 256                    월(3) 수(3)   2.0  2.6  3.9  3.0   4.4
# 257                    화(2) 목(2)   4.1  3.5  4.4  3.5   3.6
# 258                    화(3) 목(3)   3.9  3.4  4.1  3.7   3.9
# 259                    화(6) 목(6)   2.0  2.0  4.0  4.0   4.0
#
# [260 rows x 10 columns]

# %%
def sliceing(data):
    return data.split("(")[1].replace(")","")

# %%
학수번호 = list(info["학수번호"])
학수번호 = list(map(sliceing, 학수번호))
info["학수번호"] = 학수번호
info
# Out:
#      Unnamed: 0   학기 학수번호                 교수명                          강의시간  \
# 0             0  234   A0       Alexander Vos  월(5-6) 화(5-6) 수(5-6) 목(5-6)
# 1             1  233   01   David M. Docherty                    월(1) 수(1)
# 2             2  233   02   David M. Docherty                    월(2) 수(2)
# 3             3  233   03   David M. Docherty                    화(3) 목(3)
# 4             4  233   04        Anthony Hanf                    화(1) 목(1)
# ..          ...  ...  ...                 ...                           ...
# 255         255  223   84      Youn-Soo Chang                    화(4) 목(4)
# 256         256  223   85          월쉬널래그첸드라베단                    월(3) 수(3)
# 257         257  223   86      Youn-Soo Chang                    화(2) 목(2)
# 258         258  223   87      Youn-Soo Chang                    화(3) 목(3)
# 259         259  223   88  William du Plessis                    화(6) 목(6)
#
#      학습량  난이도  강의력  성취감 강의만족도
# 0    3.5  3.5  4.0  4.0   4.0
# 1    2.4  2.3  3.0  3.0   4.3
# 2    2.5  2.6  3.3  2.9   3.9
# 3    2.6  2.8  3.3  3.2   4.3
# 4    3.1  2.5  4.2  3.6   4.6
# ..   ...  ...  ...  ...   ...
# 255  4.3  3.0  4.3  3.8   4.0
# 256  2.0  2.6  3.9  3.0   4.4
# 257  4.1  3.5  4.4  3.5   3.6
# 258  3.9  3.4  4.1  3.7   3.9
# 259  2.0  2.0  4.0  4.0   4.0
#
# [260 rows x 10 columns]

# %%
def timing(data):
    data = data[:-1]
    li = data.split(" ")
    day = ""
    for i in li:
        day = f"{day}{i.split('(')[0]}, "
    time = int(li[0].split("(")[1][0])
    return day[:-2], time
강의시간 = list(info["강의시간"])
강의요일, 강의시간 = zip(*map(timing, 강의시간))
강의시간
info["강의요일"] = 강의요일
info["강의시간"] = 강의시간
info
# Out:
#      Unnamed: 0   학기 학수번호                 교수명  강의시간  학습량  난이도  강의력  성취감 강의만족도  \
# 0             0  234   A0       Alexander Vos     5  3.5  3.5  4.0  4.0   4.0
# 1             1  233   01   David M. Docherty     1  2.4  2.3  3.0  3.0   4.3
# 2             2  233   02   David M. Docherty     2  2.5  2.6  3.3  2.9   3.9
# 3             3  233   03   David M. Docherty     3  2.6  2.8  3.3  3.2   4.3
# 4             4  233   04        Anthony Hanf     1  3.1  2.5  4.2  3.6   4.6
# ..          ...  ...  ...                 ...   ...  ...  ...  ...  ...   ...
# 255         255  223   84      Youn-Soo Chang     4  4.3  3.0  4.3  3.8   4.0
# 256         256  223   85          월쉬널래그첸드라베단     3  2.0  2.6  3.9  3.0   4.4
# 257         257  223   86      Youn-Soo Chang     2  4.1  3.5  4.4  3.5   3.6
# 258         258  223   87      Youn-Soo Chang     3  3.9  3.4  4.1  3.7   3.9
# 259         259  223   88  William du Plessis     6  2.0  2.0  4.0  4.0   4.0
#
#            강의요일
# 0    월, 화, 수, 목
# 1          월, 수
# 2          월, 수
# 3          화, 목
# 4          화, 목
# ..          ...
# 255        화, 목
# 256        월, 수
# 257        화, 목
# 258        화, 목
# 259        화, 목
#
# [260 rows x 11 columns]

# %%
import numpy as np
info = info.replace('-', np.NaN)
info['학습량'] = info['학습량'].astype(float)
info['난이도'] = info['난이도'].astype(float)
info['강의력'] = info['강의력'].astype(float)
info['성취감'] = info['성취감'].astype(float)
info['강의만족도'] = info['강의만족도'].astype(float)

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  260 non-null    int64
#  1   학기          260 non-null    int64
#  2   학수번호        260 non-null    object
#  3   교수명         260 non-null    object
#  4   강의시간        260 non-null    int64
#  5   학습량         254 non-null    float64
#  6   난이도         254 non-null    float64
#  7   강의력         254 non-null    float64
#  8   성취감         254 non-null    float64
#  9   강의만족도       254 non-null    float64
#  10  강의요일        260 non-null    object
# dtypes: float64(5), int64(3), object(3)
# memory usage: 22.5+ KB

# %%
info.rename(columns={"Unnamed: 0": "강의아이디"}, inplace=True)
info
# Out:
#      강의아이디   학기 학수번호                 교수명  강의시간  학습량  난이도  강의력  성취감  강의만족도  \
# 0        0  234   A0       Alexander Vos     5  3.5  3.5  4.0  4.0    4.0
# 1        1  233   01   David M. Docherty     1  2.4  2.3  3.0  3.0    4.3
# 2        2  233   02   David M. Docherty     2  2.5  2.6  3.3  2.9    3.9
# 3        3  233   03   David M. Docherty     3  2.6  2.8  3.3  3.2    4.3
# 4        4  233   04        Anthony Hanf     1  3.1  2.5  4.2  3.6    4.6
# ..     ...  ...  ...                 ...   ...  ...  ...  ...  ...    ...
# 255    255  223   84      Youn-Soo Chang     4  4.3  3.0  4.3  3.8    4.0
# 256    256  223   85          월쉬널래그첸드라베단     3  2.0  2.6  3.9  3.0    4.4
# 257    257  223   86      Youn-Soo Chang     2  4.1  3.5  4.4  3.5    3.6
# 258    258  223   87      Youn-Soo Chang     3  3.9  3.4  4.1  3.7    3.9
# 259    259  223   88  William du Plessis     6  2.0  2.0  4.0  4.0    4.0
#
#            강의요일
# 0    월, 화, 수, 목
# 1          월, 수
# 2          월, 수
# 3          화, 목
# 4          화, 목
# ..          ...
# 255        화, 목
# 256        월, 수
# 257        화, 목
# 258        화, 목
# 259        화, 목
#
# [260 rows x 11 columns]

# %%
repu = pd.read_csv("repu.csv", index_col = 0, encoding='utf-8')
repu
# Out:
#       강의아이디         유저아이디  강의만족도  학습량  난이도  강의력  성취감  \
# 0         0           조랑말      3    3    3    3    3
# 1         0            구준      5    4    4    5    5
# 2         1            ZO      4    2    2    4    3
# 3         1        Liliki      5    2    2    3    2
# 4         1  cheoooool_13      5    2    3    3    3
# ...     ...           ...    ...  ...  ...  ...  ...
# 1234    258         orrii      4    5    3    4    5
# 1235    258        오봉집막국수      4    3    3    4    3
# 1236    258        진짜토끼없네      5    3    1    5    5
# 1237    258         Han29      4    4    4    5    3
# 1238    259         돌림힘전사      4    2    2    4    4
#
#                                                     강의평
# 0     영어 실력을 취득하기에 좋은 강의였다. 열심히 하면 좋은 성적을 받을 것이다. 최선...
# 1     강의가 하루에 두시간씩 진행되는데 한시간마다 출석체크 거의 하셨습니다. \n\n강의...
# 2     출석은 3번까지 빠져도 되지만 유고를 안 받아주십니다\n(한마디로 유고포함 3번이라...
# 3     스피킹을 잘 하신다면 도커티 교수님 강의만큼 편안한 아잉은 없습니다. 과제도 없고 ...
# 4     중간고사는 영어 원서 읽고 줄거리 및 느낀점 요약 후 교수님과 디스커션, 기말 전에...
# ...                                                 ...
# 1234  확실히 꿀강은 아님. 그러나 영어 실력이 좋지 않아도 많은 과제들을 할 시간만 있다...
# 1235  한 학기 동안 학술적 리포트 쓰는 법을 배우고 한 편을 쓰는데, 그렇게 어렵지 않고...
# 1236  공대생이면 듣기에 좋은 아카데믹잉글리쉬 강의로, 교수님이 친절하시고 이해하기 어렵지...
# 1237  영어 실력이 기본적으로 부족해서 좋은 등급을 받을거라는 기대는 하지 않았는데, 생각...
# 1238  많은 컨텐츠를 다루기 보다는 적은 내용을 반복해서 강조하십니다. \n그래서 중요한 ...
#
# [1816 rows x 8 columns]

# %%
from sqlalchemy import create_engine
import pymysql

# MariaDB 연결 문자열
db_connection_str = 'mysql+pymysql://test:1234@localhost:3306/klue_ae?charset=utf8mb4'

# SQLAlchemy 엔진 생성
db_connection = create_engine(db_connection_str)

# %%
# DataFrame을 MariaDB에 쓰기
info.to_sql(name='lecture_info', con=db_connection, if_exists='append', index=False)
repu.to_sql(name='lecture_repu', con=db_connection, if_exists='append', index=False)
# Out:
# 1816
